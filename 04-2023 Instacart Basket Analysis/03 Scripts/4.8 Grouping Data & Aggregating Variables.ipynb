# %% [markdown]
# # TASK 4.8

# %%
#Importing libraries
import pandas as pd
import numpy as np
import os

# %%
#Folder path
path = r'C:\Users\Lucero\Documents\Instacart Basket Analysis\02 Data'

# %% [markdown]
#  # Step 1

# %%
#Importing 'orders_products_merged_updated.pkl'
df_ords_prods_merged = pd.read_pickle(os.path.join(path,'Prepared Data','orders_products_merged_update.pkl'))

# %% [markdown]
# # Step 2

# %%
#Grouping data by 'department_id' and then aggregating to find mean of 'order_number'
df_ords_prods_merged.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
#Different way of finding mean of 'order_number'
df_ords_prods_merged.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# # Step 3

# %%
Now we have more 'department_id' rows displayed 21.
Most of the 'department_ids' in the full data frame have a lower mean compared to the subset. Other than number 17, which has a higher mean across the entire data frame.

# %% [markdown]
# # Step 4

# %%
#Split the data into groups based on the 'user_id' column. Apply the transform() function on the 'order_number' column to generate the max orders for each user.
df_ords_prods_merged['max_order'] = df_ords_prods_merged.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['max_order'] <= 40) & (df_ords_prods_merged['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merged.head(15)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0            0   2539329        1    prior             1                   2
# 1            1   2398795        1    prior             2                   3
# 2            2    473747        1    prior             3                   3
# 3            3   2254736        1    prior             4                   4
# 4            4    431534        1    prior             5                   4
# 5            5   3367565        1    prior             6                   2
# 6            6    550135        1    prior             7                   1
# 7            7   3108588        1    prior             8                   1
# 8            8   2295261        1    prior             9                   1
# 9            9   2550362        1    prior            10                   4
# 10         144   2968173       15    prior            15                   1
# ...

# %%
#Checking the count of 'loyalty_flag' values
df_ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
df_ords_prods_merged['loyalty_flag'].value_counts(dropna = False).sum()
# Out:
# 32404859

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 22)

# %% [markdown]
# # Step 5

# %%
#Performing multiple aggregations ('min', 'max', 'mean', 'sum')
df_ords_prods_merged.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max', 'sum']})
# Out:
#                      prices
#                        mean  min      max          sum
# loyalty_flag
# Loyal customer    10.386336  1.0  99999.0  106814042.2
# New customer      13.294670  1.0  99999.0   83011787.2
# Regular customer  12.495717  1.0  99999.0  198391693.2

# %% [markdown]
# # Step 6

# %%
#Split the data into groups based on the 'user_id' column. Apply the transform() function on the 'prices' column to generate the average prices for each user.
df_ords_prods_merged['avg_price'] = df_ords_prods_merged.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_ords_prods_merged.head(15)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0            0   2539329        1    prior             1                   2
# 1            1   2398795        1    prior             2                   3
# 2            2    473747        1    prior             3                   3
# 3            3   2254736        1    prior             4                   4
# 4            4    431534        1    prior             5                   4
# 5            5   3367565        1    prior             6                   2
# 6            6    550135        1    prior             7                   1
# 7            7   3108588        1    prior             8                   1
# 8            8   2295261        1    prior             9                   1
# 9            9   2550362        1    prior            10                   4
# 10         144   2968173       15    prior            15                   1
# ...

# %%
#Checking the count of 'spending_flag' values
df_ords_prods_merged['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     31770614
# High spender      634245
# Name: spending_flag, dtype: int64

# %%
df_ords_prods_merged['spending_flag'].value_counts(dropna = False).sum()
# Out:
# 32404859

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 24)

# %% [markdown]
# # Step 7

# %%
# Renaming column
df_ords_prods_merged.rename(columns = {'days_since_last_order' : 'days_since_prior_order'}, inplace = True)

# %%
# Checking
df_ords_prods_merged.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
# ...

# %%
#Split the data into groups based on the 'user_id' column. Apply the transform() function on the 'days_since_prior_order' column to generate the median order frequency for each user.
df_ords_prods_merged['median_freq'] = df_ords_prods_merged.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['median_freq'] > 20, 'order_freq_flag'] = 'Non-frequent customer'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['median_freq'] > 10) & (df_ords_prods_merged['median_freq'] <= 20), 'order_freq_flag'] = 'Regular customer'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['median_freq'] <= 10, 'order_freq_flag'] = 'Frequent customer'

# %%
df_ords_prods_merged.head(15)
# Out:
#     Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0            0   2539329        1    prior             1                   2
# 1            1   2398795        1    prior             2                   3
# 2            2    473747        1    prior             3                   3
# 3            3   2254736        1    prior             4                   4
# 4            4    431534        1    prior             5                   4
# 5            5   3367565        1    prior             6                   2
# 6            6    550135        1    prior             7                   1
# 7            7   3108588        1    prior             8                   1
# 8            8   2295261        1    prior             9                   1
# 9            9   2550362        1    prior            10                   4
# 10         144   2968173       15    prior            15                   1
# ...

# %%
#Checking the count of 'order_freq_flag' values
df_ords_prods_merged['order_freq_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_freq_flag, dtype: int64

# %%
df_ords_prods_merged['order_freq_flag'].value_counts(dropna = False).sum()
# Out:
# 32404859

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 26)

# %% [markdown]
# We can see that the sum of the count values of 'order_freq_flag' is equal to the total number of rows in 'df_ords_prods_merged.

# %% [markdown]
# # Step 9

# %%
# Exporting
df_ords_prods_merged.to_pickle(os.path.join(path,'Prepared Data','orders_products_merged_aggregated.pkl'))
